# %%
import pandas as pd

df = pd.read_csv('Tokopedia.csv')

df
# Out:
#                                                Produk Pelanggan  \
# 0   PAKET 3 PCS Celana Pendek Pria Distro Boardsho...     Q***s
# 1   PAKET 3 PCS Celana Pendek Pria Distro Boardsho...     T***j
# 2   PAKET 3 PCS Celana Pendek Pria Distro Boardsho...     X***e
# 3   PAKET 3 PCS Celana Pendek Pria Distro Boardsho...     C***t
# 4   Celana Pendek Boardshort Pria NOVA Twill 100% ...     S***d
# 5   PAKET 3 PCS Celana Pendek Pria Distro Boardsho...     L***y
# 6   PAKET 3 PCS Celana Pendek Pria Distro Boardsho...     F***b
# 7   PAKET 3 PCS Celana Pendek Pria Distro Boardsho...     A***q
# 8   PAKET 3 PCS Celana Pendek Pria Distro Boardsho...     O***e
# 9   PAKET 3 PCS Celana Pendek Pria Distro Boardsho...     Q***s
# 10  PAKET 3 PCS Celana Pendek Pria Distro Boardsho...     T***j
# 11  PAKET 3 PCS Celana Pendek Pria Distro Boardsho...     X***e
# 12  PAKET 3 PCS Celana Pendek Pria Distro Boardsho...     C***t
# 13  Celana Pendek Boardshort Pria NOVA Twill 100% ...     S***d
# ...
